# %%
import feedparser

# %%
# example yt feed : https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g
# example apple music feed : https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom
# Création d'une instance
news_feed = feedparser.parse('https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g')

# Propriétés du flux
print(news_feed.feed.keys())
# Out:
# dict_keys(['links', 'id', 'guidislink', 'link', 'yt_channelid', 'title', 'title_detail', 'authors', 'author_detail', 'href', 'author', 'published', 'published_parsed'])

# %%
news_feed['entries']
# Out:
# [{'id': 'yt:video:P-ACzty7G-c',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=P-ACzty7G-c',
#   'yt_videoid': 'P-ACzty7G-c',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Unboxing du Samsung Galaxy Z Fold 6📱',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Unboxing du Samsung Galaxy Z Fold 6📱'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=P-ACzty7G-c',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-19T12:14:54+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=19, tm_hour=12, tm_min=14, tm_sec=54, tm_wday=4, tm_yday=201, tm_isdst=0),
#   'updated': '2024-07-23T22:52:04+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=23, tm_hour=22, tm_min=52, tm_sec=4, tm_wday=1, tm_yday=205, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/P-ACzty7G-c?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i1.ytimg.com/vi/P-ACzty7G-c/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Unboxing du nouveau Samsung Galaxy Z Flip 6 📱\n\nEt vous ? Il vous intéresse ce smartphone 👀 ?\n\n#samsung #samsunggalaxy #galaxyzfold6 #samsunggalaxyzfold #zfold #zfold6 #samsungzfold #galaxyzfold #samsunggalaxyzfold6 #smartphone #smartphones #foldablephone #foldingphone #asmr #unboxing #unboxingvideo #unboxingasmr #asmrunboxing #techunboxing',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Unboxing du nouveau Samsung Galaxy Z Flip 6 📱\n\nEt vous ? Il vous intéresse ce smartphone 👀 ?\n\n#samsung #samsunggalaxy #galaxyzfold6 #samsunggalaxyzfold #zfold #zfold6 #samsungzfold #galaxyzfold #samsunggalaxyzfold6 #smartphone #smartphones #foldablephone #foldingphone #asmr #unboxing #unboxingvideo #unboxingasmr #asmrunboxing #techunboxing'},
#   'media_starrating': {'count': '368',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '6224'},
#   'media_community': ''},
#  {'id': 'yt:video:GHglUTjudsA',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=GHglUTjudsA',
#   'yt_videoid': 'GHglUTjudsA',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Unboxing du Samsung Galaxy Z Flip 6📱',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Unboxing du Samsung Galaxy Z Flip 6📱'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=GHglUTjudsA',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-18T14:09:20+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=18, tm_hour=14, tm_min=9, tm_sec=20, tm_wday=3, tm_yday=200, tm_isdst=0),
#   'updated': '2024-07-22T23:19:13+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=22, tm_hour=23, tm_min=19, tm_sec=13, tm_wday=0, tm_yday=204, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/GHglUTjudsA?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i4.ytimg.com/vi/GHglUTjudsA/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Unboxing du nouveau Samsung Galaxy Z Flip 6 📱\n\nEt vous ? Il vous intéresse ce smartphone 👀 ?\n\n#samsung #samsunggalaxy #galaxyzflip6 #samsunggalaxyzflip #zflip #zflip6 #samsungzflip #galaxyzflip #samsunggalaxyzflip6 #smartphone #smartphones #foldablephone #foldingphone #asmr #unboxing #unboxingvideo #unboxingasmr #asmrunboxing #techunboxing',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': '
u200b\u2060@Yanis_THORAUD \n► Montage : @\u200ccariboo_o \n► Musique du générique : https://www.alchemiaaudio.com\u200b\n\nABONNEZ-VOUS ! : \nDEVENEZ CONTRIBUTEUR·ICES :\n🥳 SUR PATREON : https://www.patreon.com/nowtech\n✌️SUR YOUTUBE : http://bit.ly/YTmembers\n🎮 SUR TWITCH : https://www.twitch.tv/nowtechteam\n👩\u200d💻🧑\u200d💻 DISCORD : https://bit.ly/nowtechDiscord\n\nSUIVEZ NOUS ! :\n► Instagram : https://www.instagram.com/nowtechteam\n► TikTok : https://www.tiktok.com/@nowtechteam\n► Threads : https://www.threads.net/@nowtechteam\n► X : https://twitter.com/NowtechTeam\n\n\nNowtech, chaîne indépendante de tests d'applications mobile et de Tech, est présentée par des passionnés qui partagent leurs avis, astuces et conseils. L'idée derrière nowtech c'est de vous offrir des tests soignés et divertissants, pas forcément liés à l'actualité et aux nouveautés, mais avec un vrai ton « homemade ». Nous pensons fondamentalement qu'il est important, en tant que consommateurs, qu'un maximum de personnes s'expriment sur les produits et nous avons voulu apporter notre pierre à l'édifice. *Les liens ci-dessus sont des liens d’affiliation vers un e-commerç ...
#   'media_starrating': {'count': '2701',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '52392'},
#   'media_community': ''},
#  {'id': 'yt:video:AI5SuAUmisg',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=AI5SuAUmisg',
#   'yt_videoid': 'AI5SuAUmisg',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Votre chien va bientôt vous parler 🐶 ?',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Votre chien va bientôt vous parler 🐶 ?'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=AI5SuAUmisg',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-12T15:33:08+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=15, tm_min=33, tm_sec=8, tm_wday=4, tm_yday=194, tm_isdst=0),
#   'updated': '2024-07-17T14:30:48+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=17, tm_hour=14, tm_min=30, tm_sec=48, tm_wday=2, tm_yday=199, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/AI5SuAUmisg?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i2.ytimg.com/vi/AI5SuAUmisg/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Et si dans un futur proche nos animaux de compagnie se mettaient à parler 😱 ?!\nC’est ce qu’aimerait rendre possible un groupe de chercheurs 🧑\u200d🔬\n\nEt vous ? Si vous pouviez parler avec votre animal de compagnie, vous le feriez 👀 ?\n\n#innovation #innovations #techinnovation #techinnovations #tech #technology #technologie #technologies #ia #ai #artificialintelligence #intelligenceartificielle #animal #animaux #animals #animauxdecompagnie #animaldecompagnie',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Et si dans un futur proche nos animaux de compagnie se mettaient à parler 😱 ?!\nC’est ce qu’aimerait rendre possible un groupe de chercheurs 🧑\u200d🔬\n\nEt vous ? Si vous pouviez parler avec votre animal de compagnie, vous le feriez 👀 ?\n\n#innovation #innovations #techinnovation #techinnovations #tech #technology #technologie #technologies #ia #ai #artificialintelligence #intelligenceartificielle #animal #animaux #animals #animauxdecompagnie #animaldecompagnie'},
#   'media_starrating': {'count': '388',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '8941'},
#   'media_community': ''},
#  {'id': 'yt:video:71lCijQ42HM',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=71lCijQ42HM',
#   'yt_videoid': '71lCijQ42HM',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'iPad Air M2 ou iPad Pro M4, lequel choisir ?',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'iPad Air M2 ou iPad Pro M4, lequel choisir ?'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=71lCijQ42HM',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-11T15:30:04+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday
n01:43 Quelle taille choisir ?\n04:07 La puissance\n06:48 Le Gaming\n10:09 Le son\n11:23 Les caméras\n12:25 L'USB-C\n13:16 L'identification\n13:37 Le Pencil\n15:34 Le stockage\n16:29 Lequel choisir ?\n---------------------------------------\xad------\n\n🔵 BOUTIQUE NOWTECH AMAZON : https://www.amazon.fr/shop/nowtech\n► Présentation : @\u200cjerome_nowtech\n► Tournage : @cariboo_o\n► Montage :  @cariboo_o\n► Musique du générique : https://www.alchemiaaudio.com/ \n\nABONNEZ-VOUS ! : http://bit.ly/19lUGZZ\n\nDEVENEZ CONTRIBUTEUR·ICES :\n🥳 SUR PATREON :  @nowtech\n✌️SUR YOUTUBE : http://bit.ly/YTmembers\n🎮 SUR TWITCH :  @nowtechteam\n👩\u200d💻🧑\u200d💻 DISCORD : https://bit.ly/nowtechDiscord\n\nSUIVEZ NOUS ! :\n► Instagram :  @nowtechteam\n► TikTok :  @nowtechteam\n► Threads : https://www.threads.net/@nowtechteam\n► X : @nowtechteam\n\nNowtech, chaîne indépendante de tests d'applications mobile et de Tech, est présentée par des passionnés qui partagent leurs avis, astuces et conseils. L'idée derrière nowtech c'est de vous offrir des tests soignés et divertissants, pas forcément liés à l'actualité et aux nouveautés, mais avec un vrai ton « homemade ». Nous pensons fondamentalement qu'il est important, en tant que consommateurs, qu'un maximum de personnes s'expriment sur les produits et nous avons voulu apporter notre pierre à l'édifice.\n\n*Les liens ci-dessus sont des liens d’affiliation vers un e-commerçant. Si vos cookies sont activés cela nous permettra de toucher un petit pourcentage sur chaque vente. Cela vous permet d’aider Nowtech sans que cela vous coûte plus cher. Merci de votre aide !\n\n#ipadproM4 #ipadairM2 #apple"},
#   'media_starrating': {'count': '2178',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '39891'},
#   'media_community': ''},
#  {'id': 'yt:video:oo_78uCzsaI',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=oo_78uCzsaI',
#   'yt_videoid': 'oo_78uCzsaI',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Samsung Unpacked : Galaxy Ring 💍',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Samsung Unpacked : Galaxy Ring 💍'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=oo_78uCzsaI',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-10T13:01:01+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=13, tm_min=1, tm_sec=1, tm_wday=2, tm_yday=192, tm_isdst=0),
#   'updated': '2024-07-14T08:36:03+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=14, tm_hour=8, tm_min=36, tm_sec=3, tm_wday=6, tm_yday=196, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/oo_78uCzsaI?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i4.ytimg.com/vi/oo_78uCzsaI/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': "Voici la Galaxy Ring de Samsung et ses principales caractéristiques 💍\n\nElle vient tout juste d'être présentée au Samsung Unpacked de Juillet 2024, et on a eu l'occasion de la prendre en main en avant-première 🤩\n\nEt vous ? Qu'est ce que vous en pensez 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyring #samsunggalaxyring #samsungring #bagueconnectée #smartring #healthtracker #sleeptracker #sporttracker #smarthealth #tech #technologie #technology #techinnovation #techlover #techlovers",
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': "Voici la Galaxy Ring de Samsung et ses principales caractéristiques 💍\n\nElle vient tout juste d'être présentée au Samsung Unpacked de Juillet 2024, et on a eu l'occasion de la prendre en main en avant-première 🤩\n\nEt vous ? Qu'est ce que vous en pensez 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyring #samsunggalaxyring #samsungring #bagueconnectée #smartring #healthtracker #sleeptracker #sporttracker #smarthealth #tech #technologie #technology #techinnovation #techlover #techlovers"},
#   'media_starrating': {'count': '938',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '41543'},
#   'media_community': ''},
#  {'id': 'yt:video:i6HiZhYzjqY',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=i6HiZhYzjqY',
#   'yt_videoid': 'i6HiZhYzjqY',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Samsung Unpacked : Galaxy Watch et Galaxy Buds⌚️🎧',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Samsung Unpacked : Galaxy Watch et Galaxy Buds⌚️🎧'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=i6HiZhYzjqY',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-10T13:00:48+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=13, tm_min=0, tm_sec=48, tm_wday=2, tm_yday=192, tm_isdst=0),
#   'updated': '2024-07-19T02:23:42+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=19, tm_hour=2, tm_min=23, tm_sec=42, tm_wday=4, tm_yday=201, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/i6HiZhYzjqY?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i2.ytimg.com/vi/i6HiZhYzjqY/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Les nouvelles Galaxy Watch Ultra et 7, ainsi que les nouveaux Galaxy Buds 3 et 3 Pro viennent d’être annoncés par Samsung et on a pu prendre en mains, en avant-première, tout ce beau monde 🤩\n\nEt vous ? Qu’est ce qui vous intéresse le plus parmi ces nouveaux produits 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxybuds #galaxybuds3 #galaxybuds3pro #samsungbuds #samsungwatch #galaxywatch #galaxywatch7 #galaxywatchultra #samsunggalaxywatch #samsunggalaxybuds #tech #technologie #technology #techinnovation #techlover #techlovers',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Les nouvelles Galaxy Watch Ultra et 7, ainsi que les nouveaux Galaxy Buds 3 et 3 Pro viennent d’être annoncés par Samsung et on a pu prendre en mains, en avant-première, tout ce beau monde 🤩\n\nEt vous ? Qu’est ce qui vous intéresse le plus parmi ces nouveaux produits 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxybuds #galaxybuds3 #galaxybuds3pro #samsungbuds #samsungwatch #galaxywatch #galaxywatch7 #galaxywatchultra #samsunggalaxywatch #samsunggalaxybuds #tech #technologie #technology #techinnovation #techlover #techlovers'},
#   'media_starrating': {'count': '594',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '14082'},
#   'media_community': ''},
#  {'id': 'yt:video:Rm5huztHW_s',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=Rm5huztHW_s',
#   'yt_videoid': 'Rm5huztHW_s',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Samsung Unpacked : Galaxy Ring (en bref) 💍',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Samsung Unpacked : Galaxy Ring (en bref) 💍'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=Rm5huztHW_s',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-10T13:00:33+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=13, tm_min=0, tm_sec=33, tm_wday=2, tm_yday=192, tm_isdst=0),
#   'updated': '2024-07-17T09:19:32+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=17, tm_hour=9, tm_min=19, tm_sec=32, tm_wday=2, tm_yday=199, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/Rm5huztHW_s?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i3.ytimg.com/vi/Rm5huztHW_s/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': "Voici, en bref, la Galaxy Ring de Samsung et ses principales caractéristiques 💍\n\nElle vient tout juste d'être présentée au Samsung Unpacked de Juillet 2024, et on a eu l'occasion de la prendre en main en avant-première 🤩\n\nEt vous ? Qu'est ce que vous en pensez 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyring #samsunggalaxyring #samsungring #bagueconnectée #smartring #healthtracker #sleeptracker #sporttracker #smarthealth #tech #technologie #technology #techinnovation #techlover #techlovers",
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': "Voici, en bref, la Galaxy Ring de Samsung et ses principales caractéristiques 💍\n\nElle vient tout juste d'être présentée au Samsung Unpacked de Juillet 2024, et on a eu l'occasion de la prendre en main en avant-première 🤩\n\nEt vous ? Qu'est ce que vous en pensez 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyring #samsunggalaxyring #samsungring #bagueconnectée #smartring #healthtracker #sleeptracker #sporttracker #smarthealth #tech #technologie #technology #techinnovation #techlover #techlovers"},
#   'media_starrating': {'count': '201',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '3427'},
#   'media_community': ''},
#  {'id': 'yt:video:6HamJOVujVM',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=6HamJOVujVM',
#   'yt_videoid': '6HamJOVujVM',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Samsung Unpacked : Galaxy Z Fold 6 🦋',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Samsung Unpacked : Galaxy Z Fold 6 🦋'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=6HamJOVujVM',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-10T13:00:08+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=13, tm_min=0, tm_sec=8, tm_wday=2, tm_yday=192, tm_isdst=0),
#   'updated': '2024-07-16T11:54:35+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=16, tm_hour=11, tm_min=54, tm_sec=35, tm_wday=1, tm_yday=198, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/6HamJOVujVM?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i3.ytimg.com/vi/6HamJOVujVM/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Le nouveau Galaxy Z Fold 6 vient d’être annoncé par Samsung et on a pu le prendre en mains en avant-première 🤩\n\nEt vous ? Est ce qu’il vous fait de l’œil ce Galaxy Z Fold 6 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyfold #galaxyfold6 #galaxyzfold #galaxyzfold6 #galaxyz #foldingphone #foldablephone #smartphone #smartphones #smartphonepliable #tech #technologie #technology #techinnovation #techlover #techlovers',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Le nouveau Galaxy Z Fold 6 vient d’être annoncé par Samsung et on a pu le prendre en mains en avant-première 🤩\n\nEt vous ? Est ce qu’il vous fait de l’œil ce Galaxy Z Fold 6 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyfold #galaxyfold6 #galaxyzfold #galaxyzfold6 #galaxyz #foldingphone #foldablephone #smartphone #smartphones #smartphonepliable #tech #technologie #technology #techinnovation #techlover #techlovers'},
#   'media_starrating': {'count': '1290',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '38335'},
#   'media_community': ''},
#  {'id': 'yt:video:au9maGidXdA',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=au9maGidXdA',
#   'yt_videoid': 'au9maGidXdA',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Samsung Unpacked : Galaxy Z Flip 6 😍',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Samsung Unpacked : Galaxy Z Flip 6 😍'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=au9maGidXdA',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-10T13:00:03+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=13, tm_min=0, tm_sec=3, tm_wday=2, tm_yday=192, tm_isdst=0),
#   'updated': '2024-07-19T04:19:42+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=19, tm_hour=4, tm_min=19, tm_sec=42, tm_wday=4, tm_yday=201, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/au9maGidXdA?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i2.ytimg.com/vi/au9maGidXdA/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Le nouveau Galaxy Z Flip 6 vient d’être annoncé par Samsung et on a pu le prendre en mains en avant-première 🤩\n\nEt vous ? Est ce qu’il vous fait de l’œil ce Galaxy Z Flip 6 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyflip #galaxyflip6 #galaxyzflip #galaxyzflip6 #galaxyz #smartphone #smartphones #foldingphone #foldablephone #smartphonepliable #tech #technologie #technology #techinnovation #techlover #techlovers',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Le nouveau Galaxy Z Flip 6 vient d’être annoncé par Samsung et on a pu le prendre en mains en avant-première 🤩\n\nEt vous ? Est ce qu’il vous fait de l’œil ce Galaxy Z Flip 6 👀 ?\n\n#samsung #samsunggalaxy #galaxy #unpacked #samsungunpacked #galaxyflip #galaxyflip6 #galaxyzflip #galaxyzflip6 #galaxyz #smartphone #smartphones #foldingphone #foldablephone #smartphonepliable #tech #technologie #technology #techinnovation #techlover #techlovers'},
#   'media_starrating': {'count': '1264',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '43659'},
#   'media_community': ''},
#  {'id': 'yt:video:CT-Of9cPPLk',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=CT-Of9cPPLk',
#   'yt_videoid': 'CT-Of9cPPLk',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Une batterie qui dure 50 ans🔋',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Une batterie qui dure 50 ans🔋'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=CT-Of9cPPLk',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-05T09:49:01+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=5, tm_hour=9, tm_min=49, tm_sec=1, tm_wday=4, tm_yday=187, tm_isdst=0),
#   'updated': '2024-07-15T05:18:48+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=15, tm_hour=5, tm_min=18, tm_sec=48, tm_wday=0, tm_yday=197, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/CT-Of9cPPLk?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i4.ytimg.com/vi/CT-Of9cPPLk/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Imaginez que vous n’ayez plus jamais besoin de recharger votre smartphone 🥰\nC’est symap hein ? Et bien arrêtez d’imaginer, voici la batterie qui pourrait en avoir l’ambition 🤩\n\nEt vous ? Vous seriez prêt à avoir ce rype de batterie dans votre smartphone 👀 ?\n\n#smartphone #telephone #phone #batterie #battery #nucleaire #nuclear #innovation #inventions #innovations #decouverte #découverte #invention #betavolt #tech #technologie #technology #techinnovation #techlover #techlovers',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Imaginez que vous n’ayez plus jamais besoin de recharger votre smartphone 🥰\nC’est symap hein ? Et bien arrêtez d’imaginer, voici la batterie qui pourrait en avoir l’ambition 🤩\n\nEt vous ? Vous seriez prêt à avoir ce rype de batterie dans votre smartphone 👀 ?\n\n#smartphone #telephone #phone #batterie #battery #nucleaire #nuclear #innovation #inventions #innovations #decouverte #découverte #invention #betavolt #tech #technologie #technology #techinnovation #techlover #techlovers'},
#   'media_starrating': {'count': '9776',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '250472'},
#   'media_community': ''},
#  {'id': 'yt:video:IMvNCoaulO0',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=IMvNCoaulO0',
#   'yt_videoid': 'IMvNCoaulO0',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Pourquoi le prix des iPhones augmente 💸 ?',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Pourquoi le prix des iPhones augmente 💸 ?'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=IMvNCoaulO0',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-04T14:11:23+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=4, tm_hour=14, tm_min=11, tm_sec=23, tm_wday=3, tm_yday=186, tm_isdst=0),
#   'updated': '2024-07-16T19:44:16+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=16, tm_hour=19, tm_min=44, tm_sec=16, tm_wday=1, tm_yday=198, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/IMvNCoaulO0?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i2.ytimg.com/vi/IMvNCoaulO0/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Les prix des iPhones viennent tout juste d’être augmentés par Apple 😭\nMais attendez… Pourquoi et qu’est ce qui s’est passé 🤔 ?\n\nEt vous ? Vous êtes pour ou contre ce type de taxe 👀 ?\n\n#apple #iphone #iphones #iphone15 #iphone15plus #iphone15pro #iphone15promax #iphonese #prix #taxe #taxes #agec #tech #technologie',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Les prix des iPhones viennent tout juste d’être augmentés par Apple 😭\nMais attendez… Pourquoi et qu’est ce qui s’est passé 🤔 ?\n\nEt vous ? Vous êtes pour ou contre ce type de taxe 👀 ?\n\n#apple #iphone #iphones #iphone15 #iphone15plus #iphone15pro #iphone15promax #iphonese #prix #taxe #taxes #agec #tech #technologie'},
#   'media_starrating': {'count': '2718',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '89394'},
#   'media_community': ''},
#  {'id': 'yt:video:LUmBtYTdIB0',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=LUmBtYTdIB0',
#   'yt_videoid': 'LUmBtYTdIB0',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Comment la Russie sème le chaos sur les réseaux 🧐 ?',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Comment la Russie sème le chaos sur les réseaux 🧐 ?'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=LUmBtYTdIB0',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-07-03T10:17:33+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=3, tm_hour=10, tm_min=17, tm_sec=33, tm_wday=2, tm_yday=185, tm_isdst=0),
#   'updated': '2024-07-17T10:23:04+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=17, tm_hour=10, tm_min=23, tm_sec=4, tm_wday=2, tm_yday=199, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/LUmBtYTdIB0?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i1.ytimg.com/vi/LUmBtYTdIB0/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'On est en plein milieu des élections législatives 2024 et la discorde est totale sur les réseaux sociaux 😱\nMais la Russie aurait peut-être bien sa part de responsabilité là dedans 🧐\n\nEt vous ? Est-ce que vous prenez de la distance avec les réseaux sociaux le temps des législatives 👀 ?\n\n#reseauxsociaux #astroturfing #legislatives #election2024 #legislative #legislatives2024 #legislative2024 #elections2024 #bot #bots #robots #robot #twitter #x #russe #russie #russes #politique #politiques',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'On est en plein milieu des élections législatives 2024 et la discorde est totale sur les réseaux sociaux 😱\nMais la Russie aurait peut-être bien sa part de responsabilité là dedans 🧐\n\nEt vous ? Est-ce que vous prenez de la distance avec les réseaux sociaux le temps des législatives 👀 ?\n\n#reseauxsociaux #astroturfing #legislatives #election2024 #legislative #legislatives2024 #legislative2024 #elections2024 #bot #bots #robots #robot #twitter #x #russe #russie #russes #politique #politiques'},
#   'media_starrating': {'count': '678',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '15460'},
#   'media_community': ''},
#  {'id': 'yt:video:FmtijFm7ds0',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=FmtijFm7ds0',
#   'yt_videoid': 'FmtijFm7ds0',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'Le PC portable qui double votre productivité ! (Asus Zenbook Duo 2024)',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Le PC portable qui double votre productivité ! (Asus Zenbook Duo 2024)'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=FmtijFm7ds0',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-06-30T15:00:15+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=30, tm_hour=15, tm_min=0, tm_sec=15, tm_wday=6, tm_yday=182, tm_isdst=0),
#   'updated': '2024-07-14T15:04:21+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=14, tm_hour=15, tm_min=4, tm_sec=21, tm_wday=6, tm_yday=196, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/FmtijFm7ds0?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i3.ytimg.com/vi/FmtijFm7ds0/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': "Avec leur nouveau PC portable à deux écrans, le Zenbook Duo 2024, Asus innove pour doubler votre productivité en ultra mobilité !\n🔴  Asus Zenbook Duo UX8406 sous Intel est disponible chez Boulanger : https://bit.ly/3znM1OS\n& Fnac : https://bit.ly/4eH5SsA\n---------------------------------------\xad------ \nINDEX\n00:00 Asus, une marque innovante\n00:56 Un PC double écran\n02:00 Toutes les positions du PC\n05:17 2 écrans OLED \n06:04 Un ensemble ultra-mobile\n06:58 Connectivité, puissance et batterie\n08:16 Configurations\n08:32 Pour qui est fait ce PC ?\n---------------------------------------\xad------\n\n🔵 BOUTIQUE NOWTECH AMAZON : https://www.amazon.fr/shop/nowtech\n► Présentation : @\u200cjerome_nowtech\n► Tournage : @cariboo_o @Yanis_THORAUD\n► Montage :  @cariboo_o\n► Musique du générique : https://www.alchemiaaudio.com/ \n\nABONNEZ-VOUS ! : http://bit.ly/19lUGZZ\n\nDEVENEZ CONTRIBUTEUR·ICES :\n🥳 SUR PATREON :  @nowtech\n✌️SUR YOUTUBE : http://bit.ly/YTmembers\n🎮 SUR TWITCH :  @nowtechteam\n👩\u200d💻🧑\u200d💻 DISCORD : https://bit.ly/nowtechDiscord\n\nSUIVEZ NOUS ! :\n► Instagram :  @nowtechteam\n► TikTok :  @nowtechteam\n► Threads : https://www.threads.net/@nowtechteam\n► X : @nowtechteam\n\nNowtech, chaîne indépendante de tests d'applications mobile et de Tech, est présentée par des passionnés qui partagent leurs avis, astuces et conseils. L'idée derrière nowtech c'est de vous offrir des tests soignés et divertissants, pas forcément liés à l'actualité et aux nouveautés, mais avec un vrai ton « homemade ». Nous pensons fondamentalement qu'il est important, en tant que consommateurs, qu'un maximum de personnes s'expriment sur les produits et nous avons voulu apporter notre pierre à l'édifice.\n\n*Les liens ci-dessus sont des liens d’affiliation vers un e-commerçant. Si vos cookies sont activés cela nous permettra de toucher un petit pourcentage sur chaque vente. Cela vous permet d’aider Nowtech sans que cela vous coûte plus cher. Merci de votre aide !\n\n#asus #zenbookduo #intelcoreultra",
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': "Avec leur nouveau PC portable à deux écrans, le Zenbook Duo 2024, Asus innove pour doubler votre productivité en ultra mobilité !\n🔴  Asus Zenbook Duo UX8406 sous Intel est disponible chez Boulanger : https://bit.ly/3znM1OS\n& Fnac : https://bit.ly/4eH5SsA\n---------------------------------------\xad------ \nINDEX\n00:00 Asus, une marque innovante\n00:56 Un PC double écran\n02:00 Toutes les positions du PC\n05:17 2 écrans OLED \n06:04 Un ensemble ultra-mobile\n06:58 Connectivité, puissance et batterie\n08:16 Configurations\n08:32 Pour qui est fait ce PC ?\n---------------------------------------\xad------\n\n🔵 BOUTIQUE NOWTECH AMAZON : https://www.amazon.fr/shop/nowtech\n► Présentation : @\u200cjerome_nowtech\n► Tournage : @cariboo_o @Yanis_THORAUD\n► Montage :  @cariboo_o\n► Musique du générique : https://www.alchemiaaudio.com/ \n\nABONNEZ-VOUS ! : http://bit.ly/19lUGZZ\n\nDEVENEZ CONTRIBUTEUR·ICES :\n🥳 SUR PATREON :  @nowtech\n✌️SUR YOUTUBE : http://bit.ly/YTmembers\n🎮 SUR TWITCH :  @nowtechteam\n👩\u200d💻🧑\u200d💻 DISCORD : https://bit.ly/nowtechDiscord\n\nSUIVEZ NOUS ! :\n► Instagram :  @nowtechteam\n► TikTok :  @nowtechteam\n► Threads : https://www.threads.net/@nowtechteam\n► X : @nowtechteam\n\nNowtech, chaîne indépendante de tests d'applications mobile et de Tech, est présentée par des passionnés qui partagent leurs avis, astuces et conseils. L'idée derrière nowtech c'est de vous offrir des tests soignés et divertissants, pas forcément liés à l'actualité et aux nouveautés, mais avec un vrai ton « homemade ». Nous pensons fondamentalement qu'il est important, en tant que consommateurs, qu'un maximum de personnes s'expriment sur les produits et nous avons voulu apporter notre pierre à l'édifice.\n\n*Les liens ci-dessus sont des liens d’affiliation vers un e-commerçant. Si vos cookies sont activés cela nous permettra de toucher un petit pourcentage sur chaque vente. Cela vous permet d’aider Nowtech sans que cela vous coûte plus cher. Merci de votre aide !\n\n#asus #zenbookduo #intelcoreultra"},
#   'media_starrating': {'count': '846',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '14540'},
#   'media_community': ''},
#  {'id': 'yt:video:65deSVMZlsk',
#   'guidislink': True,
#   'link': 'https://www.youtube.com/watch?v=65deSVMZlsk',
#   'yt_videoid': '65deSVMZlsk',
#   'yt_channelid': 'UCVwG9JHqGLfEO-4TkF-lf2g',
#   'title': 'N’achetez pas le Vision Pro sauf si… Rien 😅',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'N’achetez pas le Vision Pro sauf si… Rien 😅'},
#   'links': [{'rel': 'alternate',
#     'href': 'https://www.youtube.com/watch?v=65deSVMZlsk',
#     'type': 'text/html'}],
#   'authors': [{'name': 'Nowtech',
#     'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'}],
#   'author_detail': {'name': 'Nowtech',
#    'href': 'https://www.youtube.com/channel/UCVwG9JHqGLfEO-4TkF-lf2g'},
#   'href': '',
#   'author': 'Nowtech',
#   'published': '2024-06-28T15:34:46+00:00',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=28, tm_hour=15, tm_min=34, tm_sec=46, tm_wday=4, tm_yday=180, tm_isdst=0),
#   'updated': '2024-07-16T07:41:15+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=16, tm_hour=7, tm_min=41, tm_sec=15, tm_wday=1, tm_yday=198, tm_isdst=0),
#   'media_content': [{'url': 'https://www.youtube.com/v/65deSVMZlsk?version=3',
#     'type': 'application/x-shockwave-flash',
#     'width': '640',
#     'height': '390'}],
#   'media_thumbnail': [{'url': 'https://i3.ytimg.com/vi/65deSVMZlsk/hqdefault.jpg',
#     'width': '480',
#     'height': '360'}],
#   'summary': 'Le Vision Pro d’Apple est dès à présent disponible à la pré-commande en France, ça y est 🤩\nNous, on ne vous conseil vraiment pas de l’acheter sauf si… Rien 😅\n\nEt vous ? Vous comptez l’acheter 👀 ?\n\n#apple #visionpro #applevisionpro #vr #ar #mr #augmentedreality #realitevirtuelle #realiteaugmentee #virtualreality #spatialcomputing #tech #technology #technologie',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g',
#    'value': 'Le Vision Pro d’Apple est dès à présent disponible à la pré-commande en France, ça y est 🤩\nNous, on ne vous conseil vraiment pas de l’acheter sauf si… Rien 😅\n\nEt vous ? Vous comptez l’acheter 👀 ?\n\n#apple #visionpro #applevisionpro #vr #ar #mr #augmentedreality #realitevirtuelle #realiteaugmentee #virtualreality #spatialcomputing #tech #technology #technologie'},
#   'media_starrating': {'count': '1165',
#    'average': '5.00',
#    'min': '1',
#    'max': '5'},
#   'media_statistics': {'views': '22536'},
#   'media_community': ''}]

# %%
for v in news_feed['entries']:
    print(f"Titre : {v['title']}\nURL : {v['link']}\nID : {v['yt_videoid']}\n")
    print('-'*100)
# Out:
# Titre : Unboxing du Samsung Galaxy Z Fold 6📱
# URL : https://www.youtube.com/watch?v=P-ACzty7G-c
# ID : P-ACzty7G-c
#
# ----------------------------------------------------------------------------------------------------
# Titre : Unboxing du Samsung Galaxy Z Flip 6📱
# URL : https://www.youtube.com/watch?v=GHglUTjudsA
# ID : GHglUTjudsA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Amazon Prime Days, idée de produits utiles !
# URL : https://www.youtube.com/watch?v=AK9rE-TUy8w
# ID : AK9rE-TUy8w
#
# ----------------------------------------------------------------------------------------------------
# Titre : Votre chien va bientôt vous parler 🐶 ?
# URL : https://www.youtube.com/watch?v=AI5SuAUmisg
# ID : AI5SuAUmisg
#
# ----------------------------------------------------------------------------------------------------
# Titre : iPad Air M2 ou iPad Pro M4, lequel choisir ?
# URL : https://www.youtube.com/watch?v=71lCijQ42HM
# ID : 71lCijQ42HM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring 💍
# URL : https://www.youtube.com/watch?v=oo_78uCzsaI
# ID : oo_78uCzsaI
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Watch et Galaxy Buds⌚️🎧
# URL : https://www.youtube.com/watch?v=i6HiZhYzjqY
# ID : i6HiZhYzjqY
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring (en bref) 💍
# URL : https://www.youtube.com/watch?v=Rm5huztHW_s
# ID : Rm5huztHW_s
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Fold 6 🦋
# URL : https://www.youtube.com/watch?v=6HamJOVujVM
# ID : 6HamJOVujVM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Flip 6 😍
# URL : https://www.youtube.com/watch?v=au9maGidXdA
# ID : au9maGidXdA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Une batterie qui dure 50 ans🔋
# URL : https://www.youtube.com/watch?v=CT-Of9cPPLk
# ID : CT-Of9cPPLk
#
# ----------------------------------------------------------------------------------------------------
# Titre : Pourquoi le prix des iPhones augmente 💸 ?
# URL : https://www.youtube.com/watch?v=IMvNCoaulO0
# ID : IMvNCoaulO0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Comment la Russie sème le chaos sur les réseaux 🧐 ?
# URL : https://www.youtube.com/watch?v=LUmBtYTdIB0
# ID : LUmBtYTdIB0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Le PC portable qui double votre productivité ! (Asus Zenbook Duo 2024)
# URL : https://www.youtube.com/watch?v=FmtijFm7ds0
# ID : FmtijFm7ds0
#
# ----------------------------------------------------------------------------------------------------
# Titre : N’achetez pas le Vision Pro sauf si… Rien 😅
# URL : https://www.youtube.com/watch?v=65deSVMZlsk
# ID : 65deSVMZlsk
#
# ----------------------------------------------------------------------------------------------------

# %%
news_feed['entries'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 news_feed['entries'][0]
#
# IndexError: list index out of range

# %%
# Propriétés de chaque item du flux
print(news_feed.entries[0].keys())
news_feed.entries[0]
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'authors', 'author', 'author_detail', 'published', 'published_parsed', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'wfw_commentrss', 'slash_comments'])
# {'title': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/'}],
#  'link': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/',
#  'comments': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/#respond',
#  'authors': [{'name': 'LoKan Sardari'}],
#  'author': 'LoKan Sardari',
#  'author_detail': {'name': 'LoKan Sardari'},
#  'published': 'Thu, 25 Jul 2024 16:00:04 +0000',
#  'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=25, tm_hour=16, tm_min=0, tm_sec=4, tm_wday=3, tm_yday=207, tm_isdst=0),
#  'tags': [{'term': 'TESLA', 'scheme': None, 'label': None},
#   {'term': 'borne recharge', 'scheme': None, 'label': None},
#   {'term': 'borne type 2', 'scheme': None, 'label': None},
#   {'term': 'dynamique', 'scheme': None, 'label': None},
#   {'term': 'énergie solaire', 'scheme': None, 'label': None},
#   {'term': 'marque espagnole', 'scheme': None, 'label': None},
#   {'term': 'panneaux solaires', 'scheme': None, 'label': None},
#   {'term': 'recharge', 'scheme': None, 'label': None},
#   {'term': 'recharge à domicile', 'scheme': None, 'label': None},
#   {'term': 'recharge solaire', 'scheme': None, 'label': None},
#   {'term': 'Solaire', 'scheme': None, 'label': None},
#   {'term': 'trydan', 'scheme': None, 'label': None},
#   {'term': 'v2C trydan', 'scheme': None, 'label': None},
#   {'term': 'voiture', 'scheme': None, 'label': None},
#   {'term': 'voiture solaire', 'scheme': None, 'label': None}],
#  'id': 'https://lokan.jp/?p=38927',
#  'guidislink': False,
#  'summary': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.'},
#  'wfw_commentrss': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/feed/',
#  'slash_comments': '0'}

# %%
for entry in news_feed.entries:
    print(f"{entry.title} --> {entry.link}")
    
# Récupération du deernier feed (dernier bulletin CERT-FR)
for i in range(0, len(news_feed.entries)):
    if i == (len(news_feed.entries)-1):
        print("Alert: {} \nLink: {}".format(news_feed.entries[0]['title'], news_feed.entries[0]['id']))

# %%
from datetime import datetime

# Given date string
date_string = "Thu, 25 Jul 2024 16:00:04 +0000"

# Parse the date string into a datetime object
dt = datetime.strptime(date_string, "%a, %d %b %Y %H:%M:%S %z")

# Convert the datetime object to a timestamp
timestamp = dt.timestamp()

print(timestamp)
# Out:
# 1721923204.0
