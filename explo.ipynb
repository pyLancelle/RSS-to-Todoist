# %%
import feedparser
import json

# %%
f = open('feeds.json')


data = json.load(f)


for s in data['feeds_type']:
    if s['support'] == 'Podcast':
        print(s['podcasts'])
# Out:
# [{'podcast': 'Colinterview', 'url': 'https://anchor.fm/s/58c40bdc/podcast/rss', 'tags': ['football']}, {'podcast': 'Speakeasy by /influx', 'url': 'https://feeds.acast.com/public/shows/628df9fa4d69b700130ba262', 'tags': ['tech', 'dev perso']}]

# %%
# example yt feed : https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g
# example apple music feed : https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom
# Création d'une instance
news_feed = feedparser.parse('https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom')

# Propriétés du flux
print(news_feed.feed.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'icon', 'logo', 'id', 'guidislink', 'updated', 'updated_parsed', 'authors', 'author_detail', 'author'])

# %%
news_feed
# Out:
# {'bozo': False,
#  'entries': [{'title': 'Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single'},
#    'published': '2024-06-24T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=176, tm_isdst=0),
#    'updated': '2024-06-24T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=176, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/e1/f7/56/e1f75693-48b2-4d40-83cb-efe01965542e/198588574881.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single<br />℗ 2024 Nesyu Beats'}],
#    'summary': '<a href="https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/e1/f7/56/e1f75693-48b2-4d40-83cb-efe01965542e/198588574881.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single<br />℗ 2024 Nesyu Beats'},
#   {'title': 'Nesyu Beats - Elle Veut (feat. Soolking, Booba, Makar, Stromae & Marwa Loud) - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Nesyu Beats - Elle Veut (feat. Soolking, Booba, Makar, Stromae & Marwa Loud) - Single'},
#    'published': '2024-06-13T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=13, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=165, tm_isdst=0),
#    'updated': '2024-06-13T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=13, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=165, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/elle-veut-feat-soolking-booba-makar-stromae-marwa-loud/1755418554?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/elle-veut-feat-soolking-booba-makar-stromae-marwa-loud/1755418554?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/elle-veut-feat-soolking-booba-makar-stromae-marwa-loud/1755418554?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/elle-veut-feat-soolking-booba-makar-stromae-marwa-loud/1755418554?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/24/a1/92/24a1926d-d268-435f-b3d5-4fdbcd843e6b/198588569221.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Elle Veut (feat. Soolking, Booba, Makar, Stromae & Marwa Loud) - Single<br />℗ 2024 Nesyu Beats'}],
#    'summary': '<a href="https://music.apple.com/us/album/elle-veut-feat-soolking-booba-makar-stromae-marwa-loud/1755418554?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/24/a1/92/24a1926d-d268-435f-b3d5-4fdbcd843e6b/198588569221.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Elle Veut (feat. Soolking, Booba, Makar, Stromae & Marwa Loud) - Single<br />℗ 2024 Nesyu Beats'},
#   {'title': 'SubLife, Booba & Ghenda - Saga (Remix) - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'SubLife, Booba & Ghenda - Saga (Remix) - Single'},
#    'published': '2024-06-13T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=13, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=165, tm_isdst=0),
#    'updated': '2024-06-13T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=13, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=165, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/saga-remix-single/1751537449?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/saga-remix-single/1751537449?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/saga-remix-single/1751537449?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/saga-remix-single/1751537449?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/ee/0b/ad/ee0badf5-588a-27bf-1528-ec51d7535bd9/24UMGIM64509.rgb.jpg/100x100bb.jpg" /></a><br /><br />SubLife, Booba & Ghenda - Saga (Remix) - Single<br />℗ 2024 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/saga-remix-single/1751537449?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/ee/0b/ad/ee0badf5-588a-27bf-1528-ec51d7535bd9/24UMGIM64509.rgb.jpg/100x100bb.jpg" /></a><br /><br />SubLife, Booba & Ghenda - Saga (Remix) - Single<br />℗ 2024 Tallac Records'},
#   {'title': 'Booba & Snight B - Dolce Camara (Remix) [feat. SDM] - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Booba & Snight B - Dolce Camara (Remix) [feat. SDM] - Single'},
#    'published': '2024-04-25T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=4, tm_mday=25, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=116, tm_isdst=0),
#    'updated': '2024-04-25T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=4, tm_mday=25, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=116, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/dolce-camara-remix-feat-sdm-single/1742586643?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/dolce-camara-remix-feat-sdm-single/1742586643?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/dolce-camara-remix-feat-sdm-single/1742586643?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/dolce-camara-remix-feat-sdm-single/1742586643?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/a2/74/4b/a2744b0a-4070-c6ed-c1f2-bd8510d216a2/24UMGIM46812.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba & Snight B - Dolce Camara (Remix) [feat. SDM] - Single<br />℗ 2024 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/dolce-camara-remix-feat-sdm-single/1742586643?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/a2/74/4b/a2744b0a-4070-c6ed-c1f2-bd8510d216a2/24UMGIM46812.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba & Snight B - Dolce Camara (Remix) [feat. SDM] - Single<br />℗ 2024 Tallac Records'},
#   {'title': 'Booba - AD VITAM ÆTERNAM',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Booba - AD VITAM ÆTERNAM'},
#    'published': '2024-02-09T08:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=2, tm_mday=9, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=40, tm_isdst=0),
#    'updated': '2024-02-09T08:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=2, tm_mday=9, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=40, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/ad-vitam-%C3%A6ternam/1729545246?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/ad-vitam-%C3%A6ternam/1729545246?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/ad-vitam-%C3%A6ternam/1729545246?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/ad-vitam-%C3%A6ternam/1729545246?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/08/cf/c9/08cfc9e9-fb3c-03cd-c6ef-45a64aba953c/24UMGIM11836.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - AD VITAM ÆTERNAM<br />℗ 2024 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/ad-vitam-%C3%A6ternam/1729545246?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/08/cf/c9/08cfc9e9-fb3c-03cd-c6ef-45a64aba953c/24UMGIM11836.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - AD VITAM ÆTERNAM<br />℗ 2024 Tallac Records'},
#   {'title': 'Booba - 6G - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Booba - 6G - Single'},
#    'published': '2024-02-02T08:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=2, tm_mday=2, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=33, tm_isdst=0),
#    'updated': '2024-02-02T08:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2024, tm_mon=2, tm_mday=2, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=33, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/6g-single/1728299479?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/6g-single/1728299479?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/6g-single/1728299479?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/6g-single/1728299479?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/1a/ad/36/1aad36de-c7f8-e873-671e-efac118677e5/24UMGIM08854.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - 6G - Single<br />℗ 2024 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/6g-single/1728299479?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/1a/ad/36/1aad36de-c7f8-e873-671e-efac118677e5/24UMGIM08854.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - 6G - Single<br />℗ 2024 Tallac Records'},
#   {'title': 'Eliasno N-P - Cocolia (feat. Booba) - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Eliasno N-P - Cocolia (feat. Booba) - Single'},
#    'published': '2023-09-20T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=9, tm_mday=20, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=263, tm_isdst=0),
#    'updated': '2023-09-20T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2023, tm_mon=9, tm_mday=20, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=263, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/cocolia-feat-booba-single/1717456972?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/cocolia-feat-booba-single/1717456972?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/cocolia-feat-booba-single/1717456972?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/cocolia-feat-booba-single/1717456972?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/c6/77/e5/c677e5a4-b87d-000c-b45d-093e5e264d23/47312_c7e9e974431c2d18c8ef7549011058cf.jpg/100x100bb.jpg" /></a><br /><br />Eliasno N-P - Cocolia (feat. Booba) - Single<br />℗ 2023 Black Power Musiq / Keyzit'}],
#    'summary': '<a href="https://music.apple.com/us/album/cocolia-feat-booba-single/1717456972?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/c6/77/e5/c677e5a4-b87d-000c-b45d-093e5e264d23/47312_c7e9e974431c2d18c8ef7549011058cf.jpg/100x100bb.jpg" /></a><br /><br />Eliasno N-P - Cocolia (feat. Booba) - Single<br />℗ 2023 Black Power Musiq / Keyzit'},
#   {'title': 'Booba - Sport Billy - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Booba - Sport Billy - Single'},
#    'published': '2023-11-17T08:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=17, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=321, tm_isdst=0),
#    'updated': '2023-11-17T08:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=17, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=321, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/sport-billy-single/1716380839?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/sport-billy-single/1716380839?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/sport-billy-single/1716380839?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/sport-billy-single/1716380839?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/36/9e/e4/369ee46e-350b-b074-6e2c-91ebac1420cb/23UM1IM53071.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - Sport Billy - Single<br />℗ 2023 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/sport-billy-single/1716380839?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/36/9e/e4/369ee46e-350b-b074-6e2c-91ebac1420cb/23UM1IM53071.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - Sport Billy - Single<br />℗ 2023 Tallac Records'},
#   {'title': 'Booba - Signé - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Booba - Signé - Single'},
#    'published': '2023-06-16T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=6, tm_mday=16, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=167, tm_isdst=0),
#    'updated': '2023-06-16T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2023, tm_mon=6, tm_mday=16, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=167, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/sign%C3%A9-single/1690589632?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/sign%C3%A9-single/1690589632?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/sign%C3%A9-single/1690589632?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/sign%C3%A9-single/1690589632?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/c2/1e/b6/c21eb654-8ec4-0506-f95f-bae5842bff2b/23UMGIM63783.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - Signé - Single<br />℗ 2023 Tallac Records'}],
#    'summary': '<a href="https://music.apple.com/us/album/sign%C3%A9-single/1690589632?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/c2/1e/b6/c21eb654-8ec4-0506-f95f-bae5842bff2b/23UMGIM63783.rgb.jpg/100x100bb.jpg" /></a><br /><br />Booba - Signé - Single<br />℗ 2023 Tallac Records'},
#   {'title': 'Chaax - Le Code (feat. Booba) - Single',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#     'value': 'Chaax - Le Code (feat. Booba) - Single'},
#    'published': '2023-05-02T07:00:00+00:00',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=5, tm_mday=2, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=122, tm_isdst=0),
#    'updated': '2023-05-02T07:00:00+00:00',
#    'updated_parsed': time.struct_time(tm_year=2023, tm_mon=5, tm_mday=2, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=122, tm_isdst=0),
#    'id': 'https://music.apple.com/us/album/le-code-feat-booba-single/1685255985?uo=4',
#    'guidislink': True,
#    'link': 'https://music.apple.com/us/album/le-code-feat-booba-single/1685255985?uo=4',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://music.apple.com/us/album/le-code-feat-booba-single/1685255985?uo=4'}],
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#      'value': '<a href="https://music.apple.com/us/album/le-code-feat-booba-single/1685255985?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/98/af/65/98af651a-005c-31d3-bb5e-168ee5ab93b3/23UMGIM49280.rgb.jpg/100x100bb.jpg" /></a><br /><br />Chaax - Le Code (feat. Booba) - Single<br />℗ 2023 92i'}],
#    'summary': '<a href="https://music.apple.com/us/album/le-code-feat-booba-single/1685255985?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/98/af/65/98af651a-005c-31d3-bb5e-168ee5ab93b3/23UMGIM49280.rgb.jpg/100x100bb.jpg" /></a><br /><br />Chaax - Le Code (feat. Booba) - Single<br />℗ 2023 92i'}],
#  'feed': {'title': 'Apple Music',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#    'value': 'Apple Music'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.apple.com'},
#    {'rel': 'self',
#     'type': 'application/atom+xml',
#     'href': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom'}],
#   'link': 'https://www.apple.com',
#   'icon': 'https://www.apple.com/favicon.ico',
#   'logo': 'https://www.apple.com/favicon.ico',
#   'id': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#   'guidislink': False,
#   'updated': '2024-07-27T21:37:43+00:00',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=27, tm_hour=21, tm_min=37, tm_sec=43, tm_wday=5, tm_yday=209, tm_isdst=0),
#   'authors': [{'name': 'RSS-Bridge'}],
#   'author_detail': {'name': 'RSS-Bridge'},
#   'author': 'RSS-Bridge'},
#  'headers': {'server': 'nginx/1.18.0',
#   'date': 'Sat, 27 Jul 2024 23:00:25 GMT',
#   'content-type': 'application/atom+xml; charset=UTF-8',
#   'transfer-encoding': 'chunked',
#   'connection': 'close',
#   'last-modified': 'Sat, 27 Jul 2024 21:37:43 GMT',
#   'rss-bridge': 'This is a cached response'},
#  'updated': 'Sat, 27 Jul 2024 21:37:43 GMT',
#  'updated_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=27, tm_hour=21, tm_min=37, tm_sec=43, tm_wday=5, tm_yday=209, tm_isdst=0),
#  'href': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'atom10',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom',
#   'media': 'http://search.yahoo.com/mrss/'}}

# %%
for v in news_feed['entries']:
    print(f"Titre : {v['title']}\nURL : {v['link']}\nID : {v['yt_videoid']}\n")
    print('-'*100)
# Out:
# Titre : Unboxing du Samsung Galaxy Z Fold 6📱
# URL : https://www.youtube.com/watch?v=P-ACzty7G-c
# ID : P-ACzty7G-c
#
# ----------------------------------------------------------------------------------------------------
# Titre : Unboxing du Samsung Galaxy Z Flip 6📱
# URL : https://www.youtube.com/watch?v=GHglUTjudsA
# ID : GHglUTjudsA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Amazon Prime Days, idée de produits utiles !
# URL : https://www.youtube.com/watch?v=AK9rE-TUy8w
# ID : AK9rE-TUy8w
#
# ----------------------------------------------------------------------------------------------------
# Titre : Votre chien va bientôt vous parler 🐶 ?
# URL : https://www.youtube.com/watch?v=AI5SuAUmisg
# ID : AI5SuAUmisg
#
# ----------------------------------------------------------------------------------------------------
# Titre : iPad Air M2 ou iPad Pro M4, lequel choisir ?
# URL : https://www.youtube.com/watch?v=71lCijQ42HM
# ID : 71lCijQ42HM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring 💍
# URL : https://www.youtube.com/watch?v=oo_78uCzsaI
# ID : oo_78uCzsaI
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Watch et Galaxy Buds⌚️🎧
# URL : https://www.youtube.com/watch?v=i6HiZhYzjqY
# ID : i6HiZhYzjqY
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring (en bref) 💍
# URL : https://www.youtube.com/watch?v=Rm5huztHW_s
# ID : Rm5huztHW_s
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Fold 6 🦋
# URL : https://www.youtube.com/watch?v=6HamJOVujVM
# ID : 6HamJOVujVM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Flip 6 😍
# URL : https://www.youtube.com/watch?v=au9maGidXdA
# ID : au9maGidXdA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Une batterie qui dure 50 ans🔋
# URL : https://www.youtube.com/watch?v=CT-Of9cPPLk
# ID : CT-Of9cPPLk
#
# ----------------------------------------------------------------------------------------------------
# Titre : Pourquoi le prix des iPhones augmente 💸 ?
# URL : https://www.youtube.com/watch?v=IMvNCoaulO0
# ID : IMvNCoaulO0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Comment la Russie sème le chaos sur les réseaux 🧐 ?
# URL : https://www.youtube.com/watch?v=LUmBtYTdIB0
# ID : LUmBtYTdIB0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Le PC portable qui double votre productivité ! (Asus Zenbook Duo 2024)
# URL : https://www.youtube.com/watch?v=FmtijFm7ds0
# ID : FmtijFm7ds0
#
# ----------------------------------------------------------------------------------------------------
# Titre : N’achetez pas le Vision Pro sauf si… Rien 😅
# URL : https://www.youtube.com/watch?v=65deSVMZlsk
# ID : 65deSVMZlsk
#
# ----------------------------------------------------------------------------------------------------

# %%
news_feed['entries'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 news_feed['entries'][0]
#
# IndexError: list index out of range

# %%
# Propriétés de chaque item du flux
print(news_feed.entries[0].keys())
news_feed.entries[0]
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'authors', 'author', 'author_detail', 'published', 'published_parsed', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'wfw_commentrss', 'slash_comments'])
# {'title': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/'}],
#  'link': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/',
#  'comments': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/#respond',
#  'authors': [{'name': 'LoKan Sardari'}],
#  'author': 'LoKan Sardari',
#  'author_detail': {'name': 'LoKan Sardari'},
#  'published': 'Thu, 25 Jul 2024 16:00:04 +0000',
#  'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=25, tm_hour=16, tm_min=0, tm_sec=4, tm_wday=3, tm_yday=207, tm_isdst=0),
#  'tags': [{'term': 'TESLA', 'scheme': None, 'label': None},
#   {'term': 'borne recharge', 'scheme': None, 'label': None},
#   {'term': 'borne type 2', 'scheme': None, 'label': None},
#   {'term': 'dynamique', 'scheme': None, 'label': None},
#   {'term': 'énergie solaire', 'scheme': None, 'label': None},
#   {'term': 'marque espagnole', 'scheme': None, 'label': None},
#   {'term': 'panneaux solaires', 'scheme': None, 'label': None},
#   {'term': 'recharge', 'scheme': None, 'label': None},
#   {'term': 'recharge à domicile', 'scheme': None, 'label': None},
#   {'term': 'recharge solaire', 'scheme': None, 'label': None},
#   {'term': 'Solaire', 'scheme': None, 'label': None},
#   {'term': 'trydan', 'scheme': None, 'label': None},
#   {'term': 'v2C trydan', 'scheme': None, 'label': None},
#   {'term': 'voiture', 'scheme': None, 'label': None},
#   {'term': 'voiture solaire', 'scheme': None, 'label': None}],
#  'id': 'https://lokan.jp/?p=38927',
#  'guidislink': False,
#  'summary': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.'},
#  'wfw_commentrss': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/feed/',
#  'slash_comments': '0'}

# %%
for entry in news_feed.entries:
    print(f"{entry.title} --> {entry.link}")
    
# Récupération du deernier feed (dernier bulletin CERT-FR)
for i in range(0, len(news_feed.entries)):
    if i == (len(news_feed.entries)-1):
        print("Alert: {} \nLink: {}".format(news_feed.entries[0]['title'], news_feed.entries[0]['id']))

# %%
from datetime import datetime

# Given date string
date_string = "Thu, 25 Jul 2024 16:00:04 +0000"

# Parse the date string into a datetime object
dt = datetime.strptime(date_string, "%a, %d %b %Y %H:%M:%S %z")

# Convert the datetime object to a timestamp
timestamp = dt.timestamp()

print(timestamp)
# Out:
# 1721923204.0
