# %%
import feedparser
import json

# %%
f = open('feeds.json')


data = json.load(f)

# %%
for a in data:
    print(a)
# Out:
# feeds_type

# %%
f = open('feeds.json')


data = json.load(f)


for s in data['feeds_type']:
    if s['support'] == 'Podcast':
        print(s['podcasts'])
# Out:
# [{'podcast': 'Colinterview', 'url': 'https://anchor.fm/s/58c40bdc/podcast/rss', 'tags': ['football']}, {'podcast': 'Speakeasy by /influx', 'url': 'https://feeds.acast.com/public/shows/628df9fa4d69b700130ba262', 'tags': ['tech', 'dev perso']}]

# %%
# example yt feed : https://www.youtube.com/feeds/videos.xml?channel_id=UCVwG9JHqGLfEO-4TkF-lf2g
# example apple music feed : https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom
# Création d'une instance
news_feed = feedparser.parse('https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom')
news_feed
# Propriétés du flux
print(news_feed.feed.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'icon', 'logo', 'id', 'guidislink', 'updated', 'updated_parsed', 'authors', 'author_detail', 'author'])

# %%
news_feed['entries'][0]
# Out:
# {'title': 'Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single',
#  'title_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#   'value': 'Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single'},
#  'published': '2024-06-24T07:00:00+00:00',
#  'published_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=176, tm_isdst=0),
#  'updated': '2024-06-24T07:00:00+00:00',
#  'updated_parsed': time.struct_time(tm_year=2024, tm_mon=6, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=176, tm_isdst=0),
#  'id': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4',
#  'guidislink': True,
#  'link': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4',
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4'}],
#  'content': [{'type': 'text/html',
#    'language': None,
#    'base': 'https://rss-bridge.org/bridge01/?action=display&bridge=AppleMusicBridge&artist=26485617&limit=10&format=Atom',
#    'value': '<a href="https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/e1/f7/56/e1f75693-48b2-4d40-83cb-efe01965542e/198588574881.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single<br />℗ 2024 Nesyu Beats'}],
#  'summary': '<a href="https://music.apple.com/us/album/avec-toi-feat-soolking-booba-maes-lynda-sdm-niska-single/1755565191?uo=4"><img src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/e1/f7/56/e1f75693-48b2-4d40-83cb-efe01965542e/198588574881.jpg/100x100bb.jpg" /></a><br /><br />Nesyu Beats - Avec Toi (feat. Soolking, Booba, Maes, Lynda, SDM & Niska) - Single<br />℗ 2024 Nesyu Beats'}

# %%
for v in news_feed['entries']:
    print(f"Titre : {v['title']}\nURL : {v['link']}\nID : {v['yt_videoid']}\n")
    print('-'*100)
# Out:
# Titre : Unboxing du Samsung Galaxy Z Fold 6📱
# URL : https://www.youtube.com/watch?v=P-ACzty7G-c
# ID : P-ACzty7G-c
#
# ----------------------------------------------------------------------------------------------------
# Titre : Unboxing du Samsung Galaxy Z Flip 6📱
# URL : https://www.youtube.com/watch?v=GHglUTjudsA
# ID : GHglUTjudsA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Amazon Prime Days, idée de produits utiles !
# URL : https://www.youtube.com/watch?v=AK9rE-TUy8w
# ID : AK9rE-TUy8w
#
# ----------------------------------------------------------------------------------------------------
# Titre : Votre chien va bientôt vous parler 🐶 ?
# URL : https://www.youtube.com/watch?v=AI5SuAUmisg
# ID : AI5SuAUmisg
#
# ----------------------------------------------------------------------------------------------------
# Titre : iPad Air M2 ou iPad Pro M4, lequel choisir ?
# URL : https://www.youtube.com/watch?v=71lCijQ42HM
# ID : 71lCijQ42HM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring 💍
# URL : https://www.youtube.com/watch?v=oo_78uCzsaI
# ID : oo_78uCzsaI
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Watch et Galaxy Buds⌚️🎧
# URL : https://www.youtube.com/watch?v=i6HiZhYzjqY
# ID : i6HiZhYzjqY
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Ring (en bref) 💍
# URL : https://www.youtube.com/watch?v=Rm5huztHW_s
# ID : Rm5huztHW_s
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Fold 6 🦋
# URL : https://www.youtube.com/watch?v=6HamJOVujVM
# ID : 6HamJOVujVM
#
# ----------------------------------------------------------------------------------------------------
# Titre : Samsung Unpacked : Galaxy Z Flip 6 😍
# URL : https://www.youtube.com/watch?v=au9maGidXdA
# ID : au9maGidXdA
#
# ----------------------------------------------------------------------------------------------------
# Titre : Une batterie qui dure 50 ans🔋
# URL : https://www.youtube.com/watch?v=CT-Of9cPPLk
# ID : CT-Of9cPPLk
#
# ----------------------------------------------------------------------------------------------------
# Titre : Pourquoi le prix des iPhones augmente 💸 ?
# URL : https://www.youtube.com/watch?v=IMvNCoaulO0
# ID : IMvNCoaulO0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Comment la Russie sème le chaos sur les réseaux 🧐 ?
# URL : https://www.youtube.com/watch?v=LUmBtYTdIB0
# ID : LUmBtYTdIB0
#
# ----------------------------------------------------------------------------------------------------
# Titre : Le PC portable qui double votre productivité ! (Asus Zenbook Duo 2024)
# URL : https://www.youtube.com/watch?v=FmtijFm7ds0
# ID : FmtijFm7ds0
#
# ----------------------------------------------------------------------------------------------------
# Titre : N’achetez pas le Vision Pro sauf si… Rien 😅
# URL : https://www.youtube.com/watch?v=65deSVMZlsk
# ID : 65deSVMZlsk
#
# ----------------------------------------------------------------------------------------------------

# %%
news_feed['entries'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 news_feed['entries'][0]
#
# IndexError: list index out of range

# %%
# Propriétés de chaque item du flux
print(news_feed.entries[0].keys())
news_feed.entries[0]
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'authors', 'author', 'author_detail', 'published', 'published_parsed', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'wfw_commentrss', 'slash_comments'])
# {'title': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '🚘 V2C Trydan : Chargez grâce à vos panneaux solaires'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/'}],
#  'link': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/',
#  'comments': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/#respond',
#  'authors': [{'name': 'LoKan Sardari'}],
#  'author': 'LoKan Sardari',
#  'author_detail': {'name': 'LoKan Sardari'},
#  'published': 'Thu, 25 Jul 2024 16:00:04 +0000',
#  'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=25, tm_hour=16, tm_min=0, tm_sec=4, tm_wday=3, tm_yday=207, tm_isdst=0),
#  'tags': [{'term': 'TESLA', 'scheme': None, 'label': None},
#   {'term': 'borne recharge', 'scheme': None, 'label': None},
#   {'term': 'borne type 2', 'scheme': None, 'label': None},
#   {'term': 'dynamique', 'scheme': None, 'label': None},
#   {'term': 'énergie solaire', 'scheme': None, 'label': None},
#   {'term': 'marque espagnole', 'scheme': None, 'label': None},
#   {'term': 'panneaux solaires', 'scheme': None, 'label': None},
#   {'term': 'recharge', 'scheme': None, 'label': None},
#   {'term': 'recharge à domicile', 'scheme': None, 'label': None},
#   {'term': 'recharge solaire', 'scheme': None, 'label': None},
#   {'term': 'Solaire', 'scheme': None, 'label': None},
#   {'term': 'trydan', 'scheme': None, 'label': None},
#   {'term': 'v2C trydan', 'scheme': None, 'label': None},
#   {'term': 'voiture', 'scheme': None, 'label': None},
#   {'term': 'voiture solaire', 'scheme': None, 'label': None}],
#  'id': 'https://lokan.jp/?p=38927',
#  'guidislink': False,
#  'summary': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://lokan.jp/feed/',
#   'value': '<img alt="" class="webfeedsFeaturedVisual wp-post-image" height="720" src="https://lokan.jp/wp-content/uploads/2024/07/Test-borne-V2C-Trydan-1280x720.jpg" style="display: block; margin: auto; margin-bottom: 20px;" width="1280" />Nous avons vu dans un précédent article les différentes façon de recharger son véhicule à domicile. Parmi elles, on retrouve la borne de recharge dédiée, et aujourd’hui nous allons découvrir ensemble le modèle Trydan de chez V2C, qui propose des fonctionnalités très intéressantes.'},
#  'wfw_commentrss': 'https://lokan.jp/2024/07/25/test-v2c-trydan-recharge-voiture-panneau-solaire/feed/',
#  'slash_comments': '0'}

# %%
for entry in news_feed.entries:
    print(f"{entry.title} --> {entry.link}")
    
# Récupération du deernier feed (dernier bulletin CERT-FR)
for i in range(0, len(news_feed.entries)):
    if i == (len(news_feed.entries)-1):
        print("Alert: {} \nLink: {}".format(news_feed.entries[0]['title'], news_feed.entries[0]['id']))

# %%
from datetime import datetime

# Given date string
date_string = "Thu, 25 Jul 2024 16:00:04 +0000"

# Parse the date string into a datetime object
dt = datetime.strptime(date_string, "%a, %d %b %Y %H:%M:%S %z")

# Convert the datetime object to a timestamp
timestamp = dt.timestamp()

print(timestamp)
# Out:
# 1721923204.0

# %%
from src.todoist import TodoistApi, TodoistAuth, TaskManager

ta = TodoistAuth('d5bd4336da1f5cabea70766409fc1dffddc33fc0')
tapi = TodoistApi(ta)
tm = TaskManager(tapi)

# %%
tm.get_all_projects()
# Out:
# Request URL: https://api.todoist.com/rest/v2/projects
# Request Headers: {'Authorization': 'Bearer d5bd4336da1f5cabea70766409fc1dffddc33fc0'}
# Request Params: None
# Request Data: None
# Response Status Code: 200
# Response Text: [
# 	{
# 		"id": "2207842207",
# 		"parent_id": null,
# 		"order": 0,
# 		"color": "grey",
# 		"name": "Inbox",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": true,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2207842207",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299903888",
# 		"parent_id": null,
# 		"order": 0,
# 		"color": "blue",
# 		"name": "Personnel",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299903888",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2328698507",
# 		"parent_id": "2299903888",
# 		"order": 1,
# 		"color": "sky_blue",
# 		"name": "Voyages & Week-ends",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2328698507",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2321175338",
# 		"parent_id": "2299903888",
# 		"order": 2,
# 		"color": "sky_blue",
# 		"name": "Santé",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2321175338",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2309354124",
# 		"parent_id": "2299903888",
# 		"order": 3,
# 		"color": "sky_blue",
# 		"name": "Routines",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2309354124",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348209",
# 		"parent_id": "2299903888",
# 		"order": 4,
# 		"color": "sky_blue",
# 		"name": "Wishlist",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348209",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302752678",
# 		"parent_id": "2299903888",
# 		"order": 5,
# 		"color": "sky_blue",
# 		"name": "Finances personnelles",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302752678",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2301100719",
# 		"parent_id": "2299903888",
# 		"order": 6,
# 		"color": "sky_blue",
# 		"name": "Médias",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2301100719",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2300754845",
# 		"parent_id": "2301100719",
# 		"order": 7,
# 		"color": "teal",
# 		"name": "Video Games",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2300754845",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348232",
# 		"parent_id": "2300754845",
# 		"order": 8,
# 		"color": "light_blue",
# 		"name": "Stardew Valley",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348232",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299924748",
# 		"parent_id": "2299903888",
# 		"order": 9,
# 		"color": "sky_blue",
# 		"name": "Projets personnels de Data Science",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299924748",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2332245466",
# 		"parent_id": "2299924748",
# 		"order": 10,
# 		"color": "sky_blue",
# 		"name": "Todoist AI-Assistant",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2332245466",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2330554733",
# 		"parent_id": "2299924748",
# 		"order": 11,
# 		"color": "light_blue",
# 		"name": "Idées de projet",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2330554733",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299903899",
# 		"parent_id": null,
# 		"order": 12,
# 		"color": "green",
# 		"name": "Travail - Eulidia",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299903899",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2330175862",
# 		"parent_id": "2299903899",
# 		"order": 13,
# 		"color": "green",
# 		"name": "Mission #5 : Etam",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2330175862",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337062806",
# 		"parent_id": "2330175862",
# 		"order": 14,
# 		"color": "lime_green",
# 		"name": "Segmentations",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337062806",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2327330693",
# 		"parent_id": "2299903899",
# 		"order": 15,
# 		"color": "lime_green",
# 		"name": "Maître de stage - Amin",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2327330693",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2313745287",
# 		"parent_id": "2299903899",
# 		"order": 16,
# 		"color": "lime_green",
# 		"name": "Nouvelles compétences",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2313745287",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348411",
# 		"parent_id": null,
# 		"order": 17,
# 		"color": "sky_blue",
# 		"name": "Anniversaires",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348411",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302349217",
# 		"parent_id": "2302348411",
# 		"order": 18,
# 		"color": "teal",
# 		"name": "Famille",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349217",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2303357107",
# 		"parent_id": "2302348411",
# 		"order": 19,
# 		"color": "teal",
# 		"name": "Famille d'Enora",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2303357107",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302349986",
# 		"parent_id": "2302348411",
# 		"order": 20,
# 		"color": "teal",
# 		"name": "Professionnel",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349986",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302349995",
# 		"parent_id": "2302349986",
# 		"order": 21,
# 		"color": "teal",
# 		"name": "Eulidia",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349995",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302350035",
# 		"parent_id": "2302349986",
# 		"order": 22,
# 		"color": "teal",
# 		"name": "Bouygues Télécom",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302350035",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302350009",
# 		"parent_id": "2302349986",
# 		"order": 23,
# 		"color": "teal",
# 		"name": "BNP PF",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302350009",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348877",
# 		"parent_id": "2302348411",
# 		"order": 24,
# 		"color": "teal",
# 		"name": "Les Connards",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348877",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348846",
# 		"parent_id": "2302348411",
# 		"order": 25,
# 		"color": "teal",
# 		"name": "Master MAS",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348846",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302353565",
# 		"parent_id": "2302348846",
# 		"order": 26,
# 		"color": "teal",
# 		"name": "Les Golfeurs",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302353565",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348756",
# 		"parent_id": "2302348411",
# 		"order": 27,
# 		"color": "teal",
# 		"name": "Team STID",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348756",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348477",
# 		"parent_id": "2302348411",
# 		"order": 28,
# 		"color": "teal",
# 		"name": "MISsionnaire",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348477",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348682",
# 		"parent_id": "2302348411",
# 		"order": 29,
# 		"color": "teal",
# 		"name": "Lool 👀",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348682",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302353458",
# 		"parent_id": "2302348411",
# 		"order": 30,
# 		"color": "teal",
# 		"name": "Divers",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302353458",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2336934507",
# 		"parent_id": null,
# 		"order": 31,
# 		"color": "berry_red",
# 		"name": "Veille (RSS)",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2336934507",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337470496",
# 		"parent_id": "2336934507",
# 		"order": 32,
# 		"color": "red",
# 		"name": "YouTube",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337470496",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337470474",
# 		"parent_id": "2336934507",
# 		"order": 33,
# 		"color": "red",
# 		"name": "Music",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337470474",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2336934528",
# 		"parent_id": "2336934507",
# 		"order": 34,
# 		"color": "red",
# 		"name": "Podcast",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2336934528",
# 		"view_style": "list"
# 	}
# ]
# [{'id': '2207842207',
#   'parent_id': None,
#   'order': 0,
#   'color': 'grey',
#   'name': 'Inbox',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': True,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2207842207',
#   'view_style': 'list'},
#  {'id': '2299903888',
#   'parent_id': None,
#   'order': 0,
#   'color': 'blue',
#   'name': 'Personnel',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299903888',
#   'view_style': 'list'},
#  {'id': '2328698507',
#   'parent_id': '2299903888',
#   'order': 1,
#   'color': 'sky_blue',
#   'name': 'Voyages & Week-ends',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2328698507',
#   'view_style': 'list'},
#  {'id': '2321175338',
#   'parent_id': '2299903888',
#   'order': 2,
#   'color': 'sky_blue',
#   'name': 'Santé',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2321175338',
#   'view_style': 'list'},
#  {'id': '2309354124',
#   'parent_id': '2299903888',
#   'order': 3,
#   'color': 'sky_blue',
#   'name': 'Routines',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2309354124',
#   'view_style': 'list'},
#  {'id': '2302348209',
#   'parent_id': '2299903888',
#   'order': 4,
#   'color': 'sky_blue',
#   'name': 'Wishlist',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348209',
#   'view_style': 'board'},
#  {'id': '2302752678',
#   'parent_id': '2299903888',
#   'order': 5,
#   'color': 'sky_blue',
#   'name': 'Finances personnelles',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302752678',
#   'view_style': 'list'},
#  {'id': '2301100719',
#   'parent_id': '2299903888',
#   'order': 6,
#   'color': 'sky_blue',
#   'name': 'Médias',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2301100719',
#   'view_style': 'board'},
#  {'id': '2300754845',
#   'parent_id': '2301100719',
#   'order': 7,
#   'color': 'teal',
#   'name': 'Video Games',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2300754845',
#   'view_style': 'list'},
#  {'id': '2302348232',
#   'parent_id': '2300754845',
#   'order': 8,
#   'color': 'light_blue',
#   'name': 'Stardew Valley',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348232',
#   'view_style': 'list'},
#  {'id': '2299924748',
#   'parent_id': '2299903888',
#   'order': 9,
#   'color': 'sky_blue',
#   'name': 'Projets personnels de Data Science',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299924748',
#   'view_style': 'list'},
#  {'id': '2332245466',
#   'parent_id': '2299924748',
#   'order': 10,
#   'color': 'sky_blue',
#   'name': 'Todoist AI-Assistant',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2332245466',
#   'view_style': 'list'},
#  {'id': '2330554733',
#   'parent_id': '2299924748',
#   'order': 11,
#   'color': 'light_blue',
#   'name': 'Idées de projet',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2330554733',
#   'view_style': 'list'},
#  {'id': '2299903899',
#   'parent_id': None,
#   'order': 12,
#   'color': 'green',
#   'name': 'Travail - Eulidia',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299903899',
#   'view_style': 'list'},
#  {'id': '2330175862',
#   'parent_id': '2299903899',
#   'order': 13,
#   'color': 'green',
#   'name': 'Mission #5 : Etam',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2330175862',
#   'view_style': 'list'},
#  {'id': '2337062806',
#   'parent_id': '2330175862',
#   'order': 14,
#   'color': 'lime_green',
#   'name': 'Segmentations',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337062806',
#   'view_style': 'list'},
#  {'id': '2327330693',
#   'parent_id': '2299903899',
#   'order': 15,
#   'color': 'lime_green',
#   'name': 'Maître de stage - Amin',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2327330693',
#   'view_style': 'list'},
#  {'id': '2313745287',
#   'parent_id': '2299903899',
#   'order': 16,
#   'color': 'lime_green',
#   'name': 'Nouvelles compétences',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2313745287',
#   'view_style': 'list'},
#  {'id': '2302348411',
#   'parent_id': None,
#   'order': 17,
#   'color': 'sky_blue',
#   'name': 'Anniversaires',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348411',
#   'view_style': 'list'},
#  {'id': '2302349217',
#   'parent_id': '2302348411',
#   'order': 18,
#   'color': 'teal',
#   'name': 'Famille',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349217',
#   'view_style': 'board'},
#  {'id': '2303357107',
#   'parent_id': '2302348411',
#   'order': 19,
#   'color': 'teal',
#   'name': "Famille d'Enora",
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2303357107',
#   'view_style': 'board'},
#  {'id': '2302349986',
#   'parent_id': '2302348411',
#   'order': 20,
#   'color': 'teal',
#   'name': 'Professionnel',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349986',
#   'view_style': 'list'},
#  {'id': '2302349995',
#   'parent_id': '2302349986',
#   'order': 21,
#   'color': 'teal',
#   'name': 'Eulidia',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349995',
#   'view_style': 'board'},
#  {'id': '2302350035',
#   'parent_id': '2302349986',
#   'order': 22,
#   'color': 'teal',
#   'name': 'Bouygues Télécom',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302350035',
#   'view_style': 'board'},
#  {'id': '2302350009',
#   'parent_id': '2302349986',
#   'order': 23,
#   'color': 'teal',
#   'name': 'BNP PF',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302350009',
#   'view_style': 'board'},
#  {'id': '2302348877',
#   'parent_id': '2302348411',
#   'order': 24,
#   'color': 'teal',
#   'name': 'Les Connards',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348877',
#   'view_style': 'board'},
#  {'id': '2302348846',
#   'parent_id': '2302348411',
#   'order': 25,
#   'color': 'teal',
#   'name': 'Master MAS',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348846',
#   'view_style': 'board'},
#  {'id': '2302353565',
#   'parent_id': '2302348846',
#   'order': 26,
#   'color': 'teal',
#   'name': 'Les Golfeurs',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302353565',
#   'view_style': 'board'},
#  {'id': '2302348756',
#   'parent_id': '2302348411',
#   'order': 27,
#   'color': 'teal',
#   'name': 'Team STID',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348756',
#   'view_style': 'board'},
#  {'id': '2302348477',
#   'parent_id': '2302348411',
#   'order': 28,
#   'color': 'teal',
#   'name': 'MISsionnaire',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348477',
#   'view_style': 'board'},
#  {'id': '2302348682',
#   'parent_id': '2302348411',
#   'order': 29,
#   'color': 'teal',
#   'name': 'Lool 👀',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348682',
#   'view_style': 'board'},
#  {'id': '2302353458',
#   'parent_id': '2302348411',
#   'order': 30,
#   'color': 'teal',
#   'name': 'Divers',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302353458',
#   'view_style': 'board'},
#  {'id': '2336934507',
#   'parent_id': None,
#   'order': 31,
#   'color': 'berry_red',
#   'name': 'Veille (RSS)',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2336934507',
#   'view_style': 'list'},
#  {'id': '2337470496',
#   'parent_id': '2336934507',
#   'order': 32,
#   'color': 'red',
#   'name': 'YouTube',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337470496',
#   'view_style': 'list'},
#  {'id': '2337470474',
#   'parent_id': '2336934507',
#   'order': 33,
#   'color': 'red',
#   'name': 'Music',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337470474',
#   'view_style': 'list'},
#  {'id': '2336934528',
#   'parent_id': '2336934507',
#   'order': 34,
#   'color': 'red',
#   'name': 'Podcast',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2336934528',
#   'view_style': 'list'}]

# %%
tm.get_all_projects()
# Out:
# Request URL: https://api.todoist.com/rest/v2/projects
# Request Headers: {'Authorization': 'Bearer d5bd4336da1f5cabea70766409fc1dffddc33fc0'}
# Request Params: None
# Request Data: None
# Response Status Code: 200
# Response Text: [
# 	{
# 		"id": "2207842207",
# 		"parent_id": null,
# 		"order": 0,
# 		"color": "grey",
# 		"name": "Inbox",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": true,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2207842207",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299903888",
# 		"parent_id": null,
# 		"order": 0,
# 		"color": "blue",
# 		"name": "Personnel",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299903888",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2328698507",
# 		"parent_id": "2299903888",
# 		"order": 1,
# 		"color": "sky_blue",
# 		"name": "Voyages & Week-ends",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2328698507",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2321175338",
# 		"parent_id": "2299903888",
# 		"order": 2,
# 		"color": "sky_blue",
# 		"name": "Santé",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2321175338",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2309354124",
# 		"parent_id": "2299903888",
# 		"order": 3,
# 		"color": "sky_blue",
# 		"name": "Routines",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2309354124",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348209",
# 		"parent_id": "2299903888",
# 		"order": 4,
# 		"color": "sky_blue",
# 		"name": "Wishlist",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348209",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302752678",
# 		"parent_id": "2299903888",
# 		"order": 5,
# 		"color": "sky_blue",
# 		"name": "Finances personnelles",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302752678",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2301100719",
# 		"parent_id": "2299903888",
# 		"order": 6,
# 		"color": "sky_blue",
# 		"name": "Médias",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2301100719",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2300754845",
# 		"parent_id": "2301100719",
# 		"order": 7,
# 		"color": "teal",
# 		"name": "Video Games",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2300754845",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348232",
# 		"parent_id": "2300754845",
# 		"order": 8,
# 		"color": "light_blue",
# 		"name": "Stardew Valley",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348232",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299924748",
# 		"parent_id": "2299903888",
# 		"order": 9,
# 		"color": "sky_blue",
# 		"name": "Projets personnels de Data Science",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299924748",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2332245466",
# 		"parent_id": "2299924748",
# 		"order": 10,
# 		"color": "sky_blue",
# 		"name": "Todoist AI-Assistant",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2332245466",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2330554733",
# 		"parent_id": "2299924748",
# 		"order": 11,
# 		"color": "light_blue",
# 		"name": "Idées de projet",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2330554733",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2299903899",
# 		"parent_id": null,
# 		"order": 12,
# 		"color": "green",
# 		"name": "Travail - Eulidia",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2299903899",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2330175862",
# 		"parent_id": "2299903899",
# 		"order": 13,
# 		"color": "green",
# 		"name": "Mission #5 : Etam",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2330175862",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337062806",
# 		"parent_id": "2330175862",
# 		"order": 14,
# 		"color": "lime_green",
# 		"name": "Segmentations",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337062806",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2327330693",
# 		"parent_id": "2299903899",
# 		"order": 15,
# 		"color": "lime_green",
# 		"name": "Maître de stage - Amin",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2327330693",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2313745287",
# 		"parent_id": "2299903899",
# 		"order": 16,
# 		"color": "lime_green",
# 		"name": "Nouvelles compétences",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2313745287",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302348411",
# 		"parent_id": null,
# 		"order": 17,
# 		"color": "sky_blue",
# 		"name": "Anniversaires",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348411",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302349217",
# 		"parent_id": "2302348411",
# 		"order": 18,
# 		"color": "teal",
# 		"name": "Famille",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349217",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2303357107",
# 		"parent_id": "2302348411",
# 		"order": 19,
# 		"color": "teal",
# 		"name": "Famille d'Enora",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2303357107",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302349986",
# 		"parent_id": "2302348411",
# 		"order": 20,
# 		"color": "teal",
# 		"name": "Professionnel",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349986",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2302349995",
# 		"parent_id": "2302349986",
# 		"order": 21,
# 		"color": "teal",
# 		"name": "Eulidia",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302349995",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302350035",
# 		"parent_id": "2302349986",
# 		"order": 22,
# 		"color": "teal",
# 		"name": "Bouygues Télécom",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302350035",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302350009",
# 		"parent_id": "2302349986",
# 		"order": 23,
# 		"color": "teal",
# 		"name": "BNP PF",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302350009",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348877",
# 		"parent_id": "2302348411",
# 		"order": 24,
# 		"color": "teal",
# 		"name": "Les Connards",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348877",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348846",
# 		"parent_id": "2302348411",
# 		"order": 25,
# 		"color": "teal",
# 		"name": "Master MAS",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348846",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302353565",
# 		"parent_id": "2302348846",
# 		"order": 26,
# 		"color": "teal",
# 		"name": "Les Golfeurs",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302353565",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348756",
# 		"parent_id": "2302348411",
# 		"order": 27,
# 		"color": "teal",
# 		"name": "Team STID",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348756",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348477",
# 		"parent_id": "2302348411",
# 		"order": 28,
# 		"color": "teal",
# 		"name": "MISsionnaire",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348477",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302348682",
# 		"parent_id": "2302348411",
# 		"order": 29,
# 		"color": "teal",
# 		"name": "Lool 👀",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302348682",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2302353458",
# 		"parent_id": "2302348411",
# 		"order": 30,
# 		"color": "teal",
# 		"name": "Divers",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2302353458",
# 		"view_style": "board"
# 	},
# 	{
# 		"id": "2336934507",
# 		"parent_id": null,
# 		"order": 31,
# 		"color": "berry_red",
# 		"name": "Veille (RSS)",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2336934507",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337470496",
# 		"parent_id": "2336934507",
# 		"order": 32,
# 		"color": "red",
# 		"name": "YouTube",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337470496",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2337470474",
# 		"parent_id": "2336934507",
# 		"order": 33,
# 		"color": "red",
# 		"name": "Music",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2337470474",
# 		"view_style": "list"
# 	},
# 	{
# 		"id": "2336934528",
# 		"parent_id": "2336934507",
# 		"order": 34,
# 		"color": "red",
# 		"name": "Podcast",
# 		"comment_count": 0,
# 		"is_shared": false,
# 		"is_favorite": false,
# 		"is_inbox_project": false,
# 		"is_team_inbox": false,
# 		"url": "https://todoist.com/showProject?id=2336934528",
# 		"view_style": "list"
# 	}
# ]
# [{'id': '2207842207',
#   'parent_id': None,
#   'order': 0,
#   'color': 'grey',
#   'name': 'Inbox',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': True,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2207842207',
#   'view_style': 'list'},
#  {'id': '2299903888',
#   'parent_id': None,
#   'order': 0,
#   'color': 'blue',
#   'name': 'Personnel',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299903888',
#   'view_style': 'list'},
#  {'id': '2328698507',
#   'parent_id': '2299903888',
#   'order': 1,
#   'color': 'sky_blue',
#   'name': 'Voyages & Week-ends',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2328698507',
#   'view_style': 'list'},
#  {'id': '2321175338',
#   'parent_id': '2299903888',
#   'order': 2,
#   'color': 'sky_blue',
#   'name': 'Santé',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2321175338',
#   'view_style': 'list'},
#  {'id': '2309354124',
#   'parent_id': '2299903888',
#   'order': 3,
#   'color': 'sky_blue',
#   'name': 'Routines',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2309354124',
#   'view_style': 'list'},
#  {'id': '2302348209',
#   'parent_id': '2299903888',
#   'order': 4,
#   'color': 'sky_blue',
#   'name': 'Wishlist',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348209',
#   'view_style': 'board'},
#  {'id': '2302752678',
#   'parent_id': '2299903888',
#   'order': 5,
#   'color': 'sky_blue',
#   'name': 'Finances personnelles',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302752678',
#   'view_style': 'list'},
#  {'id': '2301100719',
#   'parent_id': '2299903888',
#   'order': 6,
#   'color': 'sky_blue',
#   'name': 'Médias',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2301100719',
#   'view_style': 'board'},
#  {'id': '2300754845',
#   'parent_id': '2301100719',
#   'order': 7,
#   'color': 'teal',
#   'name': 'Video Games',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2300754845',
#   'view_style': 'list'},
#  {'id': '2302348232',
#   'parent_id': '2300754845',
#   'order': 8,
#   'color': 'light_blue',
#   'name': 'Stardew Valley',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348232',
#   'view_style': 'list'},
#  {'id': '2299924748',
#   'parent_id': '2299903888',
#   'order': 9,
#   'color': 'sky_blue',
#   'name': 'Projets personnels de Data Science',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299924748',
#   'view_style': 'list'},
#  {'id': '2332245466',
#   'parent_id': '2299924748',
#   'order': 10,
#   'color': 'sky_blue',
#   'name': 'Todoist AI-Assistant',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2332245466',
#   'view_style': 'list'},
#  {'id': '2330554733',
#   'parent_id': '2299924748',
#   'order': 11,
#   'color': 'light_blue',
#   'name': 'Idées de projet',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2330554733',
#   'view_style': 'list'},
#  {'id': '2299903899',
#   'parent_id': None,
#   'order': 12,
#   'color': 'green',
#   'name': 'Travail - Eulidia',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2299903899',
#   'view_style': 'list'},
#  {'id': '2330175862',
#   'parent_id': '2299903899',
#   'order': 13,
#   'color': 'green',
#   'name': 'Mission #5 : Etam',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2330175862',
#   'view_style': 'list'},
#  {'id': '2337062806',
#   'parent_id': '2330175862',
#   'order': 14,
#   'color': 'lime_green',
#   'name': 'Segmentations',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337062806',
#   'view_style': 'list'},
#  {'id': '2327330693',
#   'parent_id': '2299903899',
#   'order': 15,
#   'color': 'lime_green',
#   'name': 'Maître de stage - Amin',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2327330693',
#   'view_style': 'list'},
#  {'id': '2313745287',
#   'parent_id': '2299903899',
#   'order': 16,
#   'color': 'lime_green',
#   'name': 'Nouvelles compétences',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2313745287',
#   'view_style': 'list'},
#  {'id': '2302348411',
#   'parent_id': None,
#   'order': 17,
#   'color': 'sky_blue',
#   'name': 'Anniversaires',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348411',
#   'view_style': 'list'},
#  {'id': '2302349217',
#   'parent_id': '2302348411',
#   'order': 18,
#   'color': 'teal',
#   'name': 'Famille',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349217',
#   'view_style': 'board'},
#  {'id': '2303357107',
#   'parent_id': '2302348411',
#   'order': 19,
#   'color': 'teal',
#   'name': "Famille d'Enora",
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2303357107',
#   'view_style': 'board'},
#  {'id': '2302349986',
#   'parent_id': '2302348411',
#   'order': 20,
#   'color': 'teal',
#   'name': 'Professionnel',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349986',
#   'view_style': 'list'},
#  {'id': '2302349995',
#   'parent_id': '2302349986',
#   'order': 21,
#   'color': 'teal',
#   'name': 'Eulidia',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302349995',
#   'view_style': 'board'},
#  {'id': '2302350035',
#   'parent_id': '2302349986',
#   'order': 22,
#   'color': 'teal',
#   'name': 'Bouygues Télécom',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302350035',
#   'view_style': 'board'},
#  {'id': '2302350009',
#   'parent_id': '2302349986',
#   'order': 23,
#   'color': 'teal',
#   'name': 'BNP PF',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302350009',
#   'view_style': 'board'},
#  {'id': '2302348877',
#   'parent_id': '2302348411',
#   'order': 24,
#   'color': 'teal',
#   'name': 'Les Connards',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348877',
#   'view_style': 'board'},
#  {'id': '2302348846',
#   'parent_id': '2302348411',
#   'order': 25,
#   'color': 'teal',
#   'name': 'Master MAS',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348846',
#   'view_style': 'board'},
#  {'id': '2302353565',
#   'parent_id': '2302348846',
#   'order': 26,
#   'color': 'teal',
#   'name': 'Les Golfeurs',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302353565',
#   'view_style': 'board'},
#  {'id': '2302348756',
#   'parent_id': '2302348411',
#   'order': 27,
#   'color': 'teal',
#   'name': 'Team STID',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348756',
#   'view_style': 'board'},
#  {'id': '2302348477',
#   'parent_id': '2302348411',
#   'order': 28,
#   'color': 'teal',
#   'name': 'MISsionnaire',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348477',
#   'view_style': 'board'},
#  {'id': '2302348682',
#   'parent_id': '2302348411',
#   'order': 29,
#   'color': 'teal',
#   'name': 'Lool 👀',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302348682',
#   'view_style': 'board'},
#  {'id': '2302353458',
#   'parent_id': '2302348411',
#   'order': 30,
#   'color': 'teal',
#   'name': 'Divers',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2302353458',
#   'view_style': 'board'},
#  {'id': '2336934507',
#   'parent_id': None,
#   'order': 31,
#   'color': 'berry_red',
#   'name': 'Veille (RSS)',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2336934507',
#   'view_style': 'list'},
#  {'id': '2337470496',
#   'parent_id': '2336934507',
#   'order': 32,
#   'color': 'red',
#   'name': 'YouTube',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337470496',
#   'view_style': 'list'},
#  {'id': '2337470474',
#   'parent_id': '2336934507',
#   'order': 33,
#   'color': 'red',
#   'name': 'Music',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2337470474',
#   'view_style': 'list'},
#  {'id': '2336934528',
#   'parent_id': '2336934507',
#   'order': 34,
#   'color': 'red',
#   'name': 'Podcast',
#   'comment_count': 0,
#   'is_shared': False,
#   'is_favorite': False,
#   'is_inbox_project': False,
#   'is_team_inbox': False,
#   'url': 'https://todoist.com/showProject?id=2336934528',
#   'view_style': 'list'}]

# %%
tm.add_section('2336934522', 'Mister MV')
# Out:
# {'id': '162768188',
#  'project_id': '2336934522',
#  'order': 17,
#  'name': 'Mister MV'}

# %%
resu
# Out:
# {'id': '162767633', 'project_id': '2336934522', 'order': 16, 'name': 'Etienne'}
