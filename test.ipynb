# %%
from src.feeds.youtube import YoutubeFeed
import datetime
import pytz

dt = datetime.datetime.fromtimestamp(1720823521, pytz.UTC)

# %%
yf = YoutubeFeed("UCFyHm4Zca54_Jj9MEb8NGKQ", dt)
yf.keywords

# %%
test = yf.parse_feed()
print(test)
# Out:
# Date video : 2024-07-27 16:00:39+00:00
# Date seuil : 2024-07-12 22:32:01+00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test = yf.parse_feed()
#       2 print(test)
#
# File ~/Documents/Projets/Dev/RSS Explorer/src/feeds/youtube.py:20, in YoutubeFeed.parse_feed(self)
#      18     print(f'Date video : {dt_upload}\nDate seuil : {self.last_run}\n\n')
#      19     if (dt_upload > self.last_run):
# ---> 20         if any(keyword in video["title"] for keyword in self.keywords):
#      21             video_feed.append({"title" : video["title"],"url" : video["link"],"date_published" : video['published']})
#      23 return video_feed
#
# TypeError: 'NoneType' object is not iterable

# %%
import feedparser

# %%
feedparser.parse(yf.channel_url)
# Out:
# {'bozo': False,
#  'entries': [{'id': 'yt:video:aI2zBaYI5tM',
#    'guidislink': True,
#    'link': 'https://www.youtube.com/watch?v=aI2zBaYI5tM',
#    'yt_videoid': 'aI2zBaYI5tM',
#    'yt_channelid': 'UC1F5QJFXcu1evMkYyXRGoaw',
#    'title': 'Je migre vers une Livebox 7 [VLOG]',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://www.youtube.com/feeds/videos.xml?channel_id=UC1F5QJFXcu1evMkYyXRGoaw',
#     'value': 'Je migre vers une Livebox 7 [VLOG]'},
#    'links': [{'rel': 'alternate',
#      'href': 'https://www.youtube.com/watch?v=aI2zBaYI5tM',
#      'type': 'text/html'}],
#    'authors': [{'name': 'LoKan Studio',
#      'href': 'https://www.youtube.com/channel/UC1F5QJFXcu1evMkYyXRGoaw'}],
#    'author_detail': {'name': 'LoKan Studio',
#     'href': 'https://www.youtube.com/channel/UC1F5QJFXcu1evMkYyXRGoaw'},
#    'href': '',
#    'author': 'LoKan Studio',
#    'published': '2024-06-30T08:00:00+00:00',
# ...
